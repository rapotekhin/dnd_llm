# %%
# export PYTHONPATH=C:\Code\dnd_llm
import sys; 
sys.path.insert(0, 'c:\\Code\\dnd_llm')
sys.path.insert(0, 'c:\\Code\\dnd_llm\\game')

# %%
import core.data as data_module
from core.data.game_state_base import MainGameState
gs = MainGameState()
data_module.game_state = gs  # loaders import from core.data — must set the module attribute
gs.load_start_data()
# Out:
# Loading locations and npcs...

# %%
gs.npcs['npc-001'].__dict__
# Out:
# {'name': 'Борик Каменный Бокал',
#  'race': Halfling,
#  'subrace': None,
#  'ethnic': None,
#  'gender': 'female',
#  'height': 71,
#  'weight': 135,
#  'age': 1056,
#  'class_type': Cleric,
#  'proficiencies': [],
#  'abilities': STR: 8 DEX: 8 CON: 8 INT: 12 WIS: 14 CHA: 16,
#  'ability_modifiers': STR: -1 DEX: -1 CON: -1 INT: 1 WIS: 2 CHA: 3,
#  'hit_points': 7,
#  'max_hit_points': 7,
#  'speed': 30,
#  'haste_timer': 0,
#  'hasted': False,
#  'xp': 0,
#  'level': 1,
#  'inventory': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'gold': 128,
#  'sc': None,
#  'conditions': [],
#  'st_advantages': [],
#  'ac_bonus': 0,
#  'multi_attack_bonus': 0,
#  'str_effect_modifier': -1,
#  'str_effect_timer': 0.0,
#  'status': 'OK',
#  'id_party': -1,
#  'OUT': False,
#  'kills': [],
#  'role': 'jeweler',
#  'prepared_spells': [],
#  'alignment': None,
#  'background': None,
#  'coins': 12800,
#  'damage_vulnerabilities': [],
#  'damage_resistances': [],
#  'damage_immunities': [],
#  'condition_advantages': [],
#  'condition_immunities': [],
#  'senses': {},
#  'features': [],
#  'class_specific': {},
#  'id': 'npc-001',
#  'description': '',
#  'location': None,
#  'quests': []}
